# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
from glob import glob
from pathlib import Path
import pandas as pd 
from pkg import *

datasets = [1,2,3]
myPaths = path.PathManager(datasets=datasets)
myProcessor = process.Processor(paths=myPaths, datasets=datasets)
params = myProcessor.get_parameters()
print(params)
f.get_counts(paths=myPaths, datasets=datasets)

myDatasetManager = data.DatasetManager(paths=myPaths, datasets=datasets)

train_loader, test_loader = f.prepare(data_manager=myDatasetManager, batch_size=10)
# Out:
# Water backgrounds initialized: 3
# {'01': {'clen': 0.15, 'photon_energy': 6000}, '02': {'clen': 0.15, 'photon_energy': 7000}, '03': {'clen': 0.15, 'photon_energy': 8000}}
# Paths refreshed for dataset ['01', '02', '03'].
# Directory: peaks/01
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/01
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/01
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/02
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/02
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/02
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/03
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/03
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/03
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Actual percentage of empty images: 33.33333333333333% across peaks, water_overlays, and labels directories.
#
# Final dataset sizes - Peaks: 135, Labels: 135, Overlays: 135
#
# Data prepared.
# Train size: 108
# Test size: 27
# Batch size: 10
# Number of batches in train_loader: 11

# %%
b = background.BackgroundSubtraction(threshold=20)
type(myPaths.total_paths.overlays)


all_data = b.main(inputs=myPaths.total_paths.overlays)
print(all_data)
# all_data.to_csv('all_data.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/cxfel/cxls_hitfinder/cnn/src/pkg/waterbackground_subtraction/finder/background.py:90, in BackgroundSubtraction.main(self, inputs)
#      89     overlay_files = inputs
# ---> 90 if isinstance(inputs, torch.tensor):
#      91     tensors = inputs
#
# TypeError: isinstance() arg 2 must be a type, a tuple of types, or a union
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 b = background.BackgroundSubtraction(threshold=20)
#       2 type(myPaths.total_paths.overlays)
# ----> 4 data = b.main(inputs=myPaths.total_paths.overlays)
#       5 # print(data)
#       6
#       7 # all_data = b.main(overlay_files=myPaths.total_paths.overlays)
#       8 # print(all_data)
#       9 # all_data.to_csv('all_data.csv')
#
# File ~/cxfel/cxls_hitfinder/cnn/src/pkg/waterbackground_subtraction/finder/background.py:93, in BackgroundSubtraction.main(self, inputs)
#      91         tensors = inputs
#      92 except:
# ---> 93     raise Exception("Invalid input type. Please provide a list of overlay image file paths or a list of tensors.")
#      95 if overlay_files:
#      96     # Example processing a single file (first file for demonstration)
#      97     # single_image_data = self.process_single_image(image_path=overlay_files[0])
#    (...)
#     102
#     103     # Processing all overlay files
#     104     batch_data = self.process_overlay_images(overlay_files=overlay_files)
#
# Exception: Invalid input type. Please provide a list of overlay image file paths or a list of tensors.

# %%
f.check_attributes(paths=myPaths, datasets=f.convert2str(datasets), dir_type='peak')
print(myProcessor.get_parameters())

f.retrieve_attributes(file_path=myPaths.total_paths.water_background[0])
f.check_attributes(paths=myPaths, datasets=f.convert2str(datasets), dir_type='label')
# Out:
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00009.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00012.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00006.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00010.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00014.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00014.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00008.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00013.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00007.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00015.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00007.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00001.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00029.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00029.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00023.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00023.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00011.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00010.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00004.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00022.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00022.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00027.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00027.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00026.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00026.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00028.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00028.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00003.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00030.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00030.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00006.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00012.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00004.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00017.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00017.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00001.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00002.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00005.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00009.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00011.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00021.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00021.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00024.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00024.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00008.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00015.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00013.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00018.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00018.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00002.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00003.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00019.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00019.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00020.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00020.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00005.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00025.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00025.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00016.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00016.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00020.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00020.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00001.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00018.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00018.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00002.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00011.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00030.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00030.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00004.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00016.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00016.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00013.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00012.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00015.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00028.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00028.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00006.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00027.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00027.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00007.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00024.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00024.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00002.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00014.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00009.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00003.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00015.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00025.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00025.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00008.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00007.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00008.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00006.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00019.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00019.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00017.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00017.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00009.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00021.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00021.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00004.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00023.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00023.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00012.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00001.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00005.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00029.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00029.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00005.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00026.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00026.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00010.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00013.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00014.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00011.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00003.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00010.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00022.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00022.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00002.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00001.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00006.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00025.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00025.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00010.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00026.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00026.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00015.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00016.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00016.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00028.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00028.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00001.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00029.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00029.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00030.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00030.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00014.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00004.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00013.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00010.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00011.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00008.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00006.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00022.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00022.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00017.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00017.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00008.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00005.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00003.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00012.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00007.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00012.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00023.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00023.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00007.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00015.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00021.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00021.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00013.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00005.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00027.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00027.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00003.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00002.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00004.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00009.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00019.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00019.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00020.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00020.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00009.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/empty_peak_03_00011.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00014.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00018.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00018.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00024.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/03/img_8keV_clen01_00024.h5:
# Expected Peak: True, Actual Peak: True
# {'01': {'clen': 0.15, 'photon_energy': 6000}, '02': {'clen': 0.15, 'photon_energy': 7000}, '03': {'clen': 0.15, 'photon_energy': 8000}}
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00002.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00015.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00020.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00020.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00009.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00004.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00006.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00005.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00010.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00007.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00027.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00027.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00019.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00019.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00001.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00014.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00001.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00029.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00029.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00008.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00009.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00011.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00003.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00017.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00017.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00014.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00004.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00022.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00022.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00013.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00016.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00016.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00005.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00012.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00007.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00011.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00021.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00021.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00013.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00018.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00018.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00028.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00028.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00012.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00026.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00026.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00008.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00002.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00003.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00010.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00030.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00030.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00025.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00025.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00006.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/empty_label_01_00015.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00024.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00024.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00023.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/01/label_img_6keV_clen01_00023.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00012.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00007.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00028.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00028.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00004.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00008.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00003.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00006.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00001.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00004.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00013.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00005.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00020.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00020.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00014.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00012.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00026.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00026.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00003.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00002.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00009.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00013.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00024.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00024.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00009.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00023.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00023.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00027.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00027.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00001.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00017.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00017.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00010.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00016.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00016.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00025.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00025.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00005.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00011.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00018.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00018.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00007.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00006.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00022.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00022.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00021.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00021.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00015.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00030.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00030.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00019.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00019.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00010.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00029.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00029.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00002.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/empty_label_02_00011.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00008.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00014.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/02/label_img_7keV_clen01_00015.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00006.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00024.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00024.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00011.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00023.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00023.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00014.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00026.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00026.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00014.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00005.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00009.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00003.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00015.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00017.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00017.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00013.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00002.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00020.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00020.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00010.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00007.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00007.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00002.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00011.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00001.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00018.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00018.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00029.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00029.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00030.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00030.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00004.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00021.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00021.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00012.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00022.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00022.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00025.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00025.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00008.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00013.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00010.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00008.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/empty_label_03_00015.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00004.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00003.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00016.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00016.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00001.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00027.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00027.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00019.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00019.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00012.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00006.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00028.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00028.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00005.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/labels/03/label_img_8keV_clen01_00009.h5:
# Expected Peak: True, Actual Peak: True
# True

# %%
f.get_counts(paths=myPaths, datasets=datasets)
# %run process_directory.py ../../images  --percent_empty 0.5 
# f.get_counts(paths=myPaths, datasets=datasets)
# Out:
# Paths refreshed for dataset ['01', '02', '03'].
# Directory: peaks/01
# 	Total files: 58
# 	Normal images: 39
# 	Empty images: 19
# Directory: labels/01
# 	Total files: 58
# 	Normal images: 39
# 	Empty images: 19
# Directory: peaks_water_overlay/01
# 	Total files: 58
# 	Normal images: 39
# 	Empty images: 19
# Directory: peaks/02
# 	Total files: 25
# 	Normal images: 17
# 	Empty images: 8
# Directory: labels/02
# 	Total files: 25
# 	Normal images: 17
# 	Empty images: 8
# Directory: peaks_water_overlay/02
# 	Total files: 25
# 	Normal images: 17
# 	Empty images: 8
# Directory: peaks/03
# 	Total files: 22
# 	Normal images: 15
# 	Empty images: 7
# Directory: labels/03
# 	Total files: 22
# 	Normal images: 15
# 	Empty images: 7
# Directory: peaks_water_overlay/03
# 	Total files: 22
# 	Normal images: 15
# 	Empty images: 7

# %%
model1 = m.BasicCNN1()
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model1.parameters(), lr=0.001)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
cfg = {
    'num_epochs': 2,
    'num_classes': 2,
    'batch_size': 10,
    'threshold':0.5,
    'loader': [train_loader,test_loader],
    'train_size': len(train_loader.dataset),
    'test_size': len(test_loader.dataset),
    'criterion': criterion,
    'optimizer': optimizer,
    'device': device,
    'model': model1,
    }

# self, model: nn.Module, loader: list, criterion, optimizer, device, cfg: dict, feature: str, labels: list
t = train_eval.TrainTestModels(model=model1, loader=[train_loader,test_loader], criterion=criterion, optimizer=optimizer, device=device, cfg=cfg, feature='peak', labels=['water','background'])
t.epoch_loop()
# Out:
# Model testing and validating: BasicCNN1
# Looking for the feature: peak
# -- epoch 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 21
#      19 # self, model: nn.Module, loader: list, criterion, optimizer, device, cfg: dict, feature: str, labels: list
#      20 t = train_eval.TrainTestModels(model=model1, loader=[train_loader,test_loader], criterion=criterion, optimizer=optimizer, device=device, cfg=cfg, feature='peak', labels=['water','background'])
# ---> 21 t.epoch_loop()
#
# File ~/Documents/vscode/CXFEL/cxls_hitfinder/cnn/src/pkg/train_eval.py:259, in TrainTestModels.epoch_loop(self)
#     256 self.logger.info('-- epoch '+str(epoch))
#     257 print('-- epoch '+str(epoch))
# --> 259 self.train(epoch)
#     260 self.test(epoch)
#
# File ~/Documents/vscode/CXFEL/cxls_hitfinder/cnn/src/pkg/train_eval.py:83, in TrainTestModels.train(self, epoch)
#      80         photon_energy_holder[image_attribute == 3.5] = 3
#      81         image_attribute = photon_energy_holder
# ---> 83     loss = self.criterion(score, image_attribute.to(self.device))
#      85 # Scales loss. Calls backward to create scaled gradients
#      86 self.scaler.scale(loss).backward()
#
# File ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/loss.py:725, in BCEWithLogitsLoss.forward(self, input, target)
#     724 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 725     return F.binary_cross_entropy_with_logits(input, target,
#     726                                               self.weight,
#     727                                               pos_weight=self.pos_weight,
#     728                                               reduction=self.reduction)
#
# File ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/functional.py:3193, in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    3190     reduction_enum = _Reduction.get_enum(reduction)
#    3192 if not (target.size() == input.size()):
# -> 3193     raise ValueError(f"Target size ({target.size()}) must be the same as input size ({input.size()})")
#    3195 return torch.binary_cross_entropy_with_logits(input, target, weight, pos_weight, reduction_enum)
#
# ValueError: Target size (torch.Size([10, 1])) must be the same as input size (torch.Size([10, 1, 2163, 2069]))

# %%
test_peaks = myPaths.get_peak_image_paths(dataset=dataset)[0]
test_water = myPaths.get_peaks_water_overlay_image_paths(dataset=dataset)[0]
test_overlay = myPaths.get_peaks_water_overlay_image_paths(dataset=dataset)[0]
param1, param2 = (0.5, 9000), (0.5, 9000, True)
f.assign_attributes(file_path=test_peaks, params=param1)
# Out:
# Attributes ['params'] assigned to /Users/adamkurth/Documents/vscode/CXFEL/cxls_hitfinder/images/peaks/01/empty_peak_01_00020.h5
