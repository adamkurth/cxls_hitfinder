# %%
from importlib import reload
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import subprocess
from glob import glob
from pkg import *
from pkg.functions import convert2int, convert2str, get_params
from typing import List, Dict, Any
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torchvision
from torchvision.ops import nms

print('PyTorch version:', torch.__version__)
print('Torchvision version:', torchvision.__version__)
print('NMS loaded successfully')
print('CUDA available:', torch.cuda.is_available())
print('CUDA version:', torch.version.cuda)
print('CUDNN version:', torch.backends.cudnn.version())
print('CUDA device count:', torch.cuda.device_count())
print('CUDA device name:', torch.cuda.get_device_name())
print('CUDA device:', torch.cuda.current_device())

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Device:{device}')
# Out:
# PyTorch version: 2.2.2
# Torchvision version: 0.17.2
# NMS loaded successfully
# CUDA available: True
# CUDA version: 11.8
# device:cuda

# %%
datasets = [1, 2, 3, 4, 5, 6, 7, 8, 9]

myPaths = path.PathManager(datasets=datasets)
myProcessor = process.Processor(paths=myPaths, datasets=datasets)
params = myProcessor.get_parameters()
print(params)
f.get_counts(paths=myPaths, datasets=datasets)
a
# myDatasetManager = data.DatasetManager(paths=myPaths, datasets=datasets)

# train_loader, test_loader = f.prepare(data_manager=myDatasetManager, batch_size=10)
# Out:
# Water backgrounds initialized: 9
# {'01': {'clen': 0.15, 'photon_energy': 6000}, '02': {'clen': 0.15, 'photon_energy': 7000}, '03': {'clen': 0.15, 'photon_energy': 8000}, '04': {'clen': 0.25, 'photon_energy': 6000}, '05': {'clen': 0.25, 'photon_energy': 7000}, '06': {'clen': 0.25, 'photon_energy': 8000}, '07': {'clen': 0.35, 'photon_energy': 6000}, '08': {'clen': 0.35, 'photon_energy': 7000}, '09': {'clen': 0.35, 'photon_energy': 8000}}
# Paths refreshed for dataset ['01', '02', '03', '04', '05', '06', '07', '08', '09'].
# Directory: peaks/01
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/01
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/01
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/02
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/02
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/02
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/03
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/03
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/03
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/04
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/04
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/04
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/05
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/05
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/05
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/06
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/06
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/06
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/07
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/07
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/07
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/08
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/08
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/08
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/09
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/09
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/09
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15

# %%
f.check_attributes(paths=myPaths, datasets=f.convert2str(datasets), dir_type='peak')
print(myProcessor.get_parameters())

# f.retrieve_attributes(file_path=myPaths.total_paths.water_background[0])
# Out:
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00009.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00012.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00006.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00010.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00014.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00014.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00014.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00008.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00013.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00007.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00015.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00007.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00001.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00029.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00029.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00023.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00023.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00011.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00010.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00004.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00022.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00022.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00027.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00027.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00026.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00026.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00028.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00028.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00003.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00030.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00030.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00006.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00006.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00012.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00004.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00017.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00017.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00001.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00002.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00005.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00009.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00011.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00021.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00021.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00024.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00024.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00008.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00008.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00015.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00013.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00018.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00018.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00002.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00003.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/empty_peak_01_00003.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00019.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00019.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00020.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00020.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00005.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00025.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00025.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00016.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/01/img_6keV_clen01_00016.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00020.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00020.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00001.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00018.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00018.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00002.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00011.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00011.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00030.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00030.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00004.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00004.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00016.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00016.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00013.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00013.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00012.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00012.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00015.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_00015.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00028.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/img_7keV_clen01_00028.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/02/empty_peak_02_
h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00029.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00007.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00007.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00022.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00022.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00002.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00002.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/empty_peak_09_00001.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/empty_peak_09_00001.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/empty_peak_09_00009.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/empty_peak_09_00009.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00028.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00028.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/empty_peak_09_00005.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/empty_peak_09_00005.h5:
# Expected Peak: False, Actual Peak: False
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00023.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00023.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00010.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00010.h5:
# Expected Peak: True, Actual Peak: True
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00021.h5 conforms to expected attributes.
# /home/amkurth/cxfel/cxls_hitfinder/images/peaks/09/img_8keV_clen03_00021.h5:
# Expected Peak: True, Actual Peak: True
# {'01': {'clen': 0.15, 'photon_energy': 6000}, '02': {'clen': 0.15, 'photon_energy': 7000}, '03': {'clen': 0.15, 'photon_energy': 8000}, '04': {'clen': 0.25, 'photon_energy': 6000}, '05': {'clen': 0.25, 'photon_energy': 7000}, '06': {'clen': 0.25, 'photon_energy': 8000}, '07': {'clen': 0.35, 'photon_energy': 6000}, '08': {'clen': 0.35, 'photon_energy': 7000}, '09': {'clen': 0.35, 'photon_energy': 8000}}

# %%
f.get_counts(paths=myPaths, datasets=datasets)
# %run process_directory.py ../../images  --percent_empty 0.5
# Out:
# Paths refreshed for dataset ['01', '02', '03', '04', '05', '06', '07', '08', '09'].
# Directory: peaks/01
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/01
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/01
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/02
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/02
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/02
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/03
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/03
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/03
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/04
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/04
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/04
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/05
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/05
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/05
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/06
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/06
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/06
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/07
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/07
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/07
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/08
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/08
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/08
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks/09
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: labels/09
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15
# Directory: peaks_water_overlay/09
# 	Total files: 45
# 	Normal images: 30
# 	Empty images: 15

# %%
myDataManager = data.DatasetManager(paths=myPaths, datasets=datasets, transform=None)


train_loader, test_loader = f.prepare(data_manager=myDataManager, batch_size=25)
# Out:
# Actual percentage of empty images: 33.33333333333333% across peaks, water_overlays, and labels directories.
#
# Final dataset sizes - Peaks: 405, Labels: 405, Overlays: 405
#
# Data prepared.
# Train size: 324
# Test size: 81
# Batch size: 25
# Number of batches in train_loader: 13

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
optimizer = optim.Adam
scheduler = ReduceLROnPlateau

cfg = {
    "loader": [train_loader, test_loader],
    'num_epochs': 15,
    'batch_size': train_loader.batch_size,
    'optimizer': optimizer,
    'device': device,
    'scheduler': scheduler
    }


peak_config = eval.Peak_Detection_Configuration(myPaths, datasets, device, save_path='../models/peak_model.pt')
print(f'weights for peak : {peak_config.get_loss_weights()}')
photon_config = eval.Photon_Energy_Configuration(myPaths, datasets, device, save_path='../models/photon_model.pt')
print(f'weights for photon energy : {photon_config.get_loss_weights()}')
clen_config = eval.Camera_Length_Configureation(myPaths, datasets, device, save_path='../models/clen_model.pt')
print(f'weights for camera length : {clen_config.get_loss_weights()}')
# Out:
# cuda
# Paths refreshed for dataset ['01', '02', '03', '04', '05', '06', '07', '08', '09'].
# weights for peak : tensor([0.5000])
# weights for photon energy : tensor([1., 1., 1.])
# weights for camera length : tensor([1., 1., 1.])

# %%
a = train_eval.TrainTestModels(cfg, peak_config)
a.epoch_loop()
a.plot_loss_accuracy()
a.plot_confusion_matrix()
a.get_confusion_matrix()
a.save_model()
# Out:
# Model testing and validating: ResNetBinaryClassifier
# Looking for the feature: peak
# -- epoch 0
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[13], line 2
#       1 a = train_eval.TrainTestModels(cfg, peak_config)
# ----> 2 a.epoch_loop()
#       3 a.plot_loss_accuracy()
#       4 a.plot_confusion_matrix()
#
# File ~/cxfel/cxls_hitfinder/cnn/src/pkg/train_eval.py:247, in TrainTestModels.epoch_loop(self)
#     244 self.logger.info('-- epoch '+str(epoch))
#     245 print('-- epoch '+str(epoch))
# --> 247 self.train(epoch)
#     248 self.test(epoch)
#     250 print(f"-- learning rate : {self.scheduler.get_last_lr()}")
#
# File ~/cxfel/cxls_hitfinder/cnn/src/pkg/train_eval.py:82, in TrainTestModels.train(self, epoch)
#      79 self.optimizer.zero_grad()
#      81 with autocast():
# ---> 82     score = self.model(i)
#      83     image_attribute = attributes[self.feature]
#      85     self.feature_class.format_image_attributes(image_attribute)
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/cxfel/cxls_hitfinder/cnn/src/pkg/models.py:457, in ResNetBinaryClassifier.forward(self, x)
#     455 def forward(self, x):
#     456     # Extract features
# --> 457     x = self.feature_extractor(x)
#     458     # Flatten the features
#     459     x = x.view(-1, self.feature_size)
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torchvision/models/resnet.py:154, in Bottleneck.forward(self, x)
#     151 out = self.bn2(out)
#     152 out = self.relu(out)
# --> 154 out = self.conv3(out)
#     155 out = self.bn3(out)
#     157 if self.downsample is not None:
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.conda/envs/newadam/lib/python3.9/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 864.00 MiB. GPU 0 has a total capacity of 79.14 GiB of which 99.50 MiB is free. Including non-PyTorch memory, this process has 79.03 GiB memory in use. Of the allocated memory 77.25 GiB is allocated by PyTorch, and 1.28 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# peak_config.get_model_diagram()

# %%
b = train_eval.TrainTestModels(cfg, photon_config)
b.epoch_loop()
b.plot_loss_accuracy()
b.plot_confusion_matrix()
b.get_confusion_matrix()
b.save_model()

# %%
c = train_eval.TrainTestModels(cfg, clen_config)
c.epoch_loop()
c.plot_loss_accuracy()
c.plot_confusion_matrix()
c.get_confusion_matrix()
c.save_model()

# %%
# reload(pipe)
# torch.cuda.synchronize()
# torch.cuda.empty_cache()
pipeline = pipe.ModelPipeline(peak_config, photon_config, clen_config, device)

# %%
# train_loader, test_loader = f.prepare(data_manager=myDataManager, batch_size=1)

# for inputs, labels, attributes in train_loader:
#     print(f'-- attributes: {attributes}')
#     results = pipeline.run(inputs.to(device))
#     print(f'-- results: {results}')
#     break
